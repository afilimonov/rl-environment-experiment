# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
MAX_ACCOUNT_BALANCE = 2147483647
MAX_NUM_SHARES = 2147483647
MAX_SHARE_PRICE = 5000
MAX_OPEN_POSITIONS = 5
MAX_STEPS = 20000

INITIAL_ACCOUNT_BALANCE = 10000

# %%
class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(StockTradingEnv, self).__init__()

        self.df = df
        self.reward_range = (0, MAX_ACCOUNT_BALANCE)

        # Actions of the format Buy x%, Sell x%, Hold, etc.
        self.action_space = spaces.Box(
            low=np.array([0, 0]), high=np.array([3, 1]), dtype=np.float16)

        # Prices contains the OHCL values for the last five prices
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(6, 6), dtype=np.float16)

    def _next_observation(self):
        # Get the stock data points for the last 5 days and scale to between 0-1
        frame = np.array([
            self.df.loc[self.current_step: self.current_step +
                        5, 'Open'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'High'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Low'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Close'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Volume'].values / MAX_NUM_SHARES,
        ])

        # Append additional data and scale each value to between 0-1
        obs = np.append(frame, [[
            self.balance / MAX_ACCOUNT_BALANCE,
            self.max_net_worth / MAX_ACCOUNT_BALANCE,
            self.shares_held / MAX_NUM_SHARES,
            self.cost_basis / MAX_SHARE_PRICE,
            self.total_shares_sold / MAX_NUM_SHARES,
            self.total_sales_value / (MAX_NUM_SHARES * MAX_SHARE_PRICE),
        ]], axis=0)

        return obs

    def _take_action(self, action):
        # Set the current price to a random price within the time step
        current_price = random.uniform(
            self.df.loc[self.current_step, "Open"], self.df.loc[self.current_step, "Close"])

        action_type = action[0]
        amount = action[1]

        if action_type < 1:
            # Buy amount % of balance in shares
            total_possible = int(self.balance / current_price)
            shares_bought = int(total_possible * amount)
            prev_cost = self.cost_basis * self.shares_held
            additional_cost = shares_bought * current_price

            self.balance -= additional_cost
            self.cost_basis = (
                prev_cost + additional_cost) / (self.shares_held + shares_bought)
            self.shares_held += shares_bought

        elif action_type < 2:
            # Sell amount % of shares held
            shares_sold = int(self.shares_held * amount)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            self.total_shares_sold += shares_sold
            self.total_sales_value += shares_sold * current_price

        self.net_worth = self.balance + self.shares_held * current_price

        if self.net_worth > self.max_net_worth:
            self.max_net_worth = self.net_worth

        if self.shares_held == 0:
            self.cost_basis = 0

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        if self.current_step > len(self.df.loc[:, 'Open'].values) - 6:
            self.current_step = 0

        delay_modifier = (self.current_step / MAX_STEPS)

        reward = self.balance * delay_modifier
        done = self.net_worth <= 0

        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        self.balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = INITIAL_ACCOUNT_BALANCE
        self.max_net_worth = INITIAL_ACCOUNT_BALANCE
        self.shares_held = 0
        self.cost_basis = 0
        self.total_shares_sold = 0
        self.total_sales_value = 0

        # Set the current step to a random point within the data frame
        self.current_step = random.randint(
            0, len(self.df.loc[:, 'Open'].values) - 6)

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        profit = self.net_worth - INITIAL_ACCOUNT_BALANCE

        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(
            f'Shares held: {self.shares_held} (Total sold: {self.total_shares_sold})')
        print(
            f'Avg cost for held shares: {self.cost_basis} (Total sales value: {self.total_sales_value})')
        print(
            f'Net worth: {self.net_worth} (Max net worth: {self.max_net_worth})')
        print(f'Profit: {profit}')

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

# %%
df = pd.read_csv('./data/AAPL.csv')
df = df.sort_values('Date')

# The algorithms require a vectorized environment to run
env = DummyVecEnv([lambda: StockTradingEnv(df)])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=20000)

obs = env.reset()
for i in range(2000):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if i % 100 == 0:
        env.render()
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe1860241d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe1860241d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe1860241d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe1860241d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe184d93518>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe184d93518>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe184d93518>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7fe184d93518>>: AttributeError: module 'gast' has no attribute 'Index'
# --------------------------------------
# | approxkl           | 6.0495677e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.34e-07     |
# | fps                | 82            |
# | n_updates          | 1             |
# | policy_entropy     | 2.838792      |
# | policy_loss        | -0.0002163588 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.1e-05       |
# | total_timesteps    | 128           |
# | value_loss         | 2658634.2     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.62119e-07   |
# | clipfrac           | 0.0           |
# | explained_variance | 1.31e-06      |
# | fps                | 588           |
# | n_updates          | 2             |
# | policy_entropy     | 2.8405898     |
# | policy_loss        | -8.391682e-06 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 1.54          |
# | total_timesteps    | 256           |
# | value_loss         | 5069503.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.3942584e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.03e-05      |
# | fps                | 593           |
# | n_updates          | 3             |
# | policy_entropy     | 2.8407633     |
# | policy_loss        | -7.451314e-05 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 1.76          |
# | total_timesteps    | 384           |
# | value_loss         | 933420.8      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.3677284e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.98e-06     |
# | fps                | 555           |
# | n_updates          | 4             |
# | policy_entropy     | 2.8408766     |
# | policy_loss        | -9.386579e-05 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 1.98          |
# | total_timesteps    | 512           |
# | value_loss         | 22766060.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.666225e-08 |
# | clipfrac           | 0.0          |
# | explained_variance | -4.17e-06    |
# | fps                | 556          |
# | n_updates          | 5            |
# | policy_entropy     | 2.8411424    |
# | policy_loss        | 2.988032e-06 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 2.21         |
# | total_timesteps    | 640          |
# | value_loss         | 23135656.0   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 8.208904e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.08e-05      |
# | fps                | 586            |
# | n_updates          | 6              |
# | policy_entropy     | 2.8399005      |
# | policy_loss        | -0.00013274723 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 2.44           |
# | total_timesteps    | 768            |
# | value_loss         | 1121615.5      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.1967434e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -7.39e-06      |
# | fps                | 593            |
# | n_updates          | 7              |
# | policy_entropy     | 2.8403294      |
# | policy_loss        | -0.00025408296 |
# | serial_timesteps   | 896            |
# | time_elapsed       | 2.66           |
# | total_timesteps    | 896            |
# | value_loss         | 16215095.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.0769788e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.36e-06     |
# | fps                | 575           |
# | n_updates          | 8             |
# | policy_entropy     | 2.84362       |
# | policy_loss        | -9.129208e-05 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.88          |
# | total_timesteps    | 1024          |
# | value_loss         | 41509100.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9290317e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.41e-05     |
# | fps                | 595           |
# | n_updates          | 9             |
# | policy_entropy     | 2.8438628     |
# | policy_loss        | -0.0007849041 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 3.1           |
# | total_timesteps    | 1152          |
# | value_loss         | 91480340.0    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.0822196e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.73e-05       |
# | fps                | 589            |
# | n_updates          | 10             |
# | policy_entropy     | 2.8432484      |
# | policy_loss        | -0.00047771574 |
# | serial_timesteps   | 1280           |
# | time_elapsed       | 3.31           |
# | total_timesteps    | 1280           |
# | value_loss         | 30895354.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.8610214e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.41e-05      |
# | fps                | 536           |
# | n_updates          | 11            |
# | policy_entropy     | 2.8416533     |
# | policy_loss        | -0.001638703  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 3.53          |
# | total_timesteps    | 1408          |
# | value_loss         | 118974800.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005780794 |
# | clipfrac           | 0.0          |
# | explained_variance | -4.05e-06    |
# | fps                | 531          |
# | n_updates          | 12           |
# | policy_entropy     | 2.8421965    |
# | policy_loss        | 9.743997e-05 |
# | serial_timesteps   | 1536         |
# | time_elapsed       | 3.77         |
# | total_timesteps    | 1536         |
# | value_loss         | 76690856.0   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0003735309  |
# | clipfrac           | 0.0           |
# | explained_variance | 1.78e-05      |
# | fps                | 510           |
# | n_updates          | 13            |
# | policy_entropy     | 2.842789      |
# | policy_loss        | -0.0012875797 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 4.01          |
# | total_timesteps    | 1664          |
# | value_loss         | 284613400.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025323714 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.25e-05      |
# | fps                | 575           |
# | n_updates          | 14            |
# | policy_entropy     | 2.844299      |
# | policy_loss        | 0.0016092756  |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 4.26          |
# | total_timesteps    | 1792          |
# | value_loss         | 654384500.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 8.701298e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -8.94e-06    |
# | fps                | 599          |
# | n_updates          | 15           |
# | policy_entropy     | 2.8427773    |
# | policy_loss        | 0.0010756388 |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 4.49         |
# | total_timesteps    | 1920         |
# | value_loss         | 1320706800.0 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00028674744  |
# | clipfrac           | 0.0            |
# | explained_variance | 6.79e-06       |
# | fps                | 595            |
# | n_updates          | 16             |
# | policy_entropy     | 2.8403833      |
# | policy_loss        | -0.00038656604 |
# | serial_timesteps   | 2048           |
# | time_elapsed       | 4.7            |
# | total_timesteps    | 2048           |
# | value_loss         | 636959500.0    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023058921 |
# | clipfrac           | 0.0           |
# | explained_variance | 8.82e-05      |
# | fps                | 595           |
# | n_updates          | 17            |
# | policy_entropy     | 2.8403094     |
# | policy_loss        | -0.0017742482 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 4.92          |
# | total_timesteps    | 2176          |
# | value_loss         | 353510270.0   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.167434e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.19e-05      |
# | fps                | 573            |
# | n_updates          | 18             |
# | policy_entropy     | 2.8399844      |
# | policy_loss        | -0.00085123617 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 5.13           |
# | total_timesteps    | 2304           |
# | value_loss         | 15832356.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00017999276 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.93e-06     |
# | fps                | 548           |
# | n_updates          | 19            |
# | policy_entropy     | 2.8392851     |
# | policy_loss        | -0.0034421335 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 5.36          |
# | total_timesteps    | 2432          |
# | value_loss         | 32080620.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00054752995 |
# | clipfrac           | 0.0           |
# | explained_variance | -7.15e-07     |
# | fps                | 583           |
# | n_updates          | 20            |
# | policy_entropy     | 2.8398733     |
# | policy_loss        | -0.0044166227 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 5.59          |
# | total_timesteps    | 2560          |
# | value_loss         | 43402496.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049012376 |
# | clipfrac           | 0.0           |
# | explained_variance | 7.87e-06      |
# | fps                | 597           |
# | n_updates          | 21            |
# | policy_entropy     | 2.8404713     |
# | policy_loss        | -0.0042063585 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 5.81          |
# | total_timesteps    | 2688          |
# | value_loss         | 15702399.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004475967  |
# | clipfrac           | 0.0           |
# | explained_variance | -1.07e-05     |
# | fps                | 598           |
# | n_updates          | 22            |
# | policy_entropy     | 2.8430033     |
# | policy_loss        | -0.0003741093 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 6.03          |
# | total_timesteps    | 2816          |
# | value_loss         | 40989776.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043916266 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.57e-05     |
# | fps                | 595           |
# | n_updates          | 23            |
# | policy_entropy     | 2.8454223     |
# | policy_loss        | -0.0046148608 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 6.24          |
# | total_timesteps    | 2944          |
# | value_loss         | 13766971.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0029429926 |
# | clipfrac           | 0.03125      |
# | explained_variance | 4.47e-06     |
# | fps                | 601          |
# | n_updates          | 24           |
# | policy_entropy     | 2.8473616    |
# | policy_loss        | -0.007896366 |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 6.46         |
# | total_timesteps    | 3072         |
# | value_loss         | 117781096.0  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003238461   |
# | clipfrac           | 0.03125       |
# | explained_variance | -1.42e-05     |
# | fps                | 598           |
# | n_updates          | 25            |
# | policy_entropy     | 2.8473833     |
# | policy_loss        | -0.0032968468 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 6.67          |
# | total_timesteps    | 3200          |
# | value_loss         | 119389400.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00062104565 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000404      |
# | fps                | 598           |
# | n_updates          | 26            |
# | policy_entropy     | 2.8467133     |
# | policy_loss        | -0.0031145473 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 6.88          |
# | total_timesteps    | 3328          |
# | value_loss         | 48755908.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011853126 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.00119      |
# | fps                | 578          |
# | n_updates          | 27           |
# | policy_entropy     | 2.846        |
# | policy_loss        | -0.008146865 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 7.1          |
# | total_timesteps    | 3456         |
# | value_loss         | 33298.523    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015791763  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.000309      |
# | fps                | 514           |
# | n_updates          | 28            |
# | policy_entropy     | 2.845776      |
# | policy_loss        | -0.0042059775 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 7.32          |
# | total_timesteps    | 3584          |
# | value_loss         | 185541.9      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015326457 |
# | clipfrac           | 0.009765625  |
# | explained_variance | -0.000972    |
# | fps                | 521          |
# | n_updates          | 29           |
# | policy_entropy     | 2.8456643    |
# | policy_loss        | -0.009597626 |
# | serial_timesteps   | 3712         |
# | time_elapsed       | 7.57         |
# | total_timesteps    | 3712         |
# | value_loss         | 231633.83    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0037720185  |
# | clipfrac           | 0.037109375   |
# | explained_variance | -0.000165     |
# | fps                | 558           |
# | n_updates          | 30            |
# | policy_entropy     | 2.8438072     |
# | policy_loss        | -0.0061499476 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 7.82          |
# | total_timesteps    | 3840          |
# | value_loss         | 6550085.0     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.480756e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000288       |
# | fps                | 512            |
# | n_updates          | 31             |
# | policy_entropy     | 2.8419755      |
# | policy_loss        | -0.00024281652 |
# | serial_timesteps   | 3968           |
# | time_elapsed       | 8.05           |
# | total_timesteps    | 3968           |
# | value_loss         | 14423764.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023474726 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.85e-05     |
# | fps                | 523           |
# | n_updates          | 32            |
# | policy_entropy     | 2.8386154     |
# | policy_loss        | -0.0027171748 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 8.3           |
# | total_timesteps    | 4096          |
# | value_loss         | 5699711.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019430239  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 5.11e-05      |
# | fps                | 506           |
# | n_updates          | 33            |
# | policy_entropy     | 2.8363824     |
# | policy_loss        | 0.00095391634 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 8.54          |
# | total_timesteps    | 4224          |
# | value_loss         | 2123109.8     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012742632  |
# | clipfrac           | 0.0            |
# | explained_variance | -3.61e-05      |
# | fps                | 560            |
# | n_updates          | 34             |
# | policy_entropy     | 2.8354607      |
# | policy_loss        | -0.00068768556 |
# | serial_timesteps   | 4352           |
# | time_elapsed       | 8.8            |
# | total_timesteps    | 4352           |
# | value_loss         | 9059432.0      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00041880543 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.4e-05       |
# | fps                | 542           |
# | n_updates          | 35            |
# | policy_entropy     | 2.8342314     |
# | policy_loss        | -0.0022110753 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 9.02          |
# | total_timesteps    | 4480          |
# | value_loss         | 11712517.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011725591  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -3.7e-06      |
# | fps                | 486           |
# | n_updates          | 36            |
# | policy_entropy     | 2.8342402     |
# | policy_loss        | -0.0035650309 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 9.26          |
# | total_timesteps    | 4608          |
# | value_loss         | 13868967.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005114429 |
# | clipfrac           | 0.0          |
# | explained_variance | -3.34e-06    |
# | fps                | 488          |
# | n_updates          | 37           |
# | policy_entropy     | 2.8326254    |
# | policy_loss        | -0.004024121 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 9.52         |
# | total_timesteps    | 4736         |
# | value_loss         | 23292854.0   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00059592037 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.85e-06      |
# | fps                | 507           |
# | n_updates          | 38            |
# | policy_entropy     | 2.8320336     |
# | policy_loss        | 0.0010481533  |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 9.79          |
# | total_timesteps    | 4864          |
# | value_loss         | 37069910.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00078308006 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.65e-05     |
# | fps                | 505           |
# | n_updates          | 39            |
# | policy_entropy     | 2.8311622     |
# | policy_loss        | -0.0009304682 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 10            |
# | total_timesteps    | 4992          |
# | value_loss         | 81158230.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00070548325 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.22e-05     |
# | fps                | 508           |
# | n_updates          | 40            |
# | policy_entropy     | 2.8310885     |
# | policy_loss        | -0.0014015646 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 10.3          |
# | total_timesteps    | 5120          |
# | value_loss         | 38764692.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00047399395 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.32e-05      |
# | fps                | 532           |
# | n_updates          | 41            |
# | policy_entropy     | 2.8297484     |
# | policy_loss        | -0.0012886197 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 5248          |
# | value_loss         | 44911268.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00077615055 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.15e-05      |
# | fps                | 579           |
# | n_updates          | 42            |
# | policy_entropy     | 2.828774      |
# | policy_loss        | 0.0042593684  |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 10.8          |
# | total_timesteps    | 5376          |
# | value_loss         | 110855280.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00038723185 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.47e-05     |
# | fps                | 453           |
# | n_updates          | 43            |
# | policy_entropy     | 2.8276372     |
# | policy_loss        | 0.0015787338  |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 11            |
# | total_timesteps    | 5504          |
# | value_loss         | 89613820.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024071473 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.6e-05      |
# | fps                | 465           |
# | n_updates          | 44            |
# | policy_entropy     | 2.827386      |
# | policy_loss        | 0.001948481   |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 5632          |
# | value_loss         | 313290980.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013936886 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -2.42e-05    |
# | fps                | 586          |
# | n_updates          | 45           |
# | policy_entropy     | 2.8275807    |
# | policy_loss        | 0.0002497133 |
# | serial_timesteps   | 5760         |
# | time_elapsed       | 11.6         |
# | total_timesteps    | 5760         |
# | value_loss         | 155354270.0  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.000288134  |
# | clipfrac           | 0.0          |
# | explained_variance | 1.62e-05     |
# | fps                | 595          |
# | n_updates          | 46           |
# | policy_entropy     | 2.826384     |
# | policy_loss        | -0.002018027 |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 11.8         |
# | total_timesteps    | 5888         |
# | value_loss         | 388956800.0  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0031646204 |
# | clipfrac           | 0.01953125   |
# | explained_variance | -1.86e-05    |
# | fps                | 564          |
# | n_updates          | 47           |
# | policy_entropy     | 2.8258953    |
# | policy_loss        | 0.0062820935 |
# | serial_timesteps   | 6016         |
# | time_elapsed       | 12           |
# | total_timesteps    | 6016         |
# | value_loss         | 361580320.0  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0011787857  |
# | clipfrac           | 0.0           |
# | explained_variance | 8.82e-06      |
# | fps                | 590           |
# | n_updates          | 48            |
# | policy_entropy     | 2.8255663     |
# | policy_loss        | -0.0019873218 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 6144          |
# | value_loss         | 436471650.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005582856 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.06e-05    |
# | fps                | 547          |
# | n_updates          | 49           |
# | policy_entropy     | 2.8267405    |
# | policy_loss        | 0.0021762028 |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 12.4         |
# | total_timesteps    | 6272         |
# | value_loss         | 982304830.0  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00020064207 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.06e-06     |
# | fps                | 532           |
# | n_updates          | 50            |
# | policy_entropy     | 2.828211      |
# | policy_loss        | -0.0015425461 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 6400          |
# | value_loss         | 1450589200.0  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0041597495 |
# | clipfrac           | 0.046875     |
# | explained_variance | 3.52e-06     |
# | fps                | 571          |
# | n_updates          | 51           |
# | policy_entropy     | 2.82863      |
# | policy_loss        | -0.015233067 |
# | serial_timesteps   | 6528         |
# | time_elapsed       | 12.9         |
# | total_timesteps    | 6528         |
# | value_loss         | 659147840.0  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0035659624 |
# | clipfrac           | 0.03515625   |
# | explained_variance | 9.54e-07     |
# | fps                | 586          |
# | n_updates          | 52           |
# | policy_entropy     | 2.8282533    |
# | policy_loss        | 0.005791536  |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 13.1         |
# | total_timesteps    | 6656         |
# | value_loss         | 1729762600.0 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012386264  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 7.15e-07      |
# | fps                | 565           |
# | n_updates          | 53            |
# | policy_entropy     | 2.8278325     |
# | policy_loss        | -0.0017920409 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 13.4          |
# | total_timesteps    | 6784          |
# | value_loss         | 2369538800.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012056812  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.38e-06     |
# | fps                | 597           |
# | n_updates          | 54            |
# | policy_entropy     | 2.8289008     |
# | policy_loss        | -0.0029146108 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 13.6          |
# | total_timesteps    | 6912          |
# | value_loss         | 730897100.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007143374 |
# | clipfrac           | 0.0          |
# | explained_variance | 5.96e-07     |
# | fps                | 599          |
# | n_updates          | 55           |
# | policy_entropy     | 2.8298514    |
# | policy_loss        | 0.002774006  |
# | serial_timesteps   | 7040         |
# | time_elapsed       | 13.8         |
# | total_timesteps    | 7040         |
# | value_loss         | 2337455000.0 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021970914 |
# | clipfrac           | 0.0           |
# | explained_variance | 7.15e-07      |
# | fps                | 600           |
# | n_updates          | 56            |
# | policy_entropy     | 2.829672      |
# | policy_loss        | 0.0004088541  |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 14            |
# | total_timesteps    | 7168          |
# | value_loss         | 4891618300.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00042107695 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.54e-07     |
# | fps                | 597           |
# | n_updates          | 57            |
# | policy_entropy     | 2.8288317     |
# | policy_loss        | 0.0024014302  |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 14.2          |
# | total_timesteps    | 7296          |
# | value_loss         | 5007576600.0  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019613155 |
# | clipfrac           | 0.0          |
# | explained_variance | 2.65e-05     |
# | fps                | 597          |
# | n_updates          | 58           |
# | policy_entropy     | 2.8299448    |
# | policy_loss        | 0.0077062305 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 14.5         |
# | total_timesteps    | 7424         |
# | value_loss         | 5287554000.0 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00050202635  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.55e-06       |
# | fps                | 545            |
# | n_updates          | 59             |
# | policy_entropy     | 2.8312383      |
# | policy_loss        | -0.00017711497 |
# | serial_timesteps   | 7552           |
# | time_elapsed       | 14.7           |
# | total_timesteps    | 7552           |
# | value_loss         | 3945978400.0   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00062439113 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.43e-06     |
# | fps                | 591           |
# | n_updates          | 60            |
# | policy_entropy     | 2.831667      |
# | policy_loss        | -0.0014021698 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 14.9          |
# | total_timesteps    | 7680          |
# | value_loss         | 2935288800.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00028292934 |
# | clipfrac           | 0.0           |
# | explained_variance | 4.17e-07      |
# | fps                | 589           |
# | n_updates          | 61            |
# | policy_entropy     | 2.8318486     |
# | policy_loss        | 0.003055342   |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 15.1          |
# | total_timesteps    | 7808          |
# | value_loss         | 4121394400.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00096445065 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.31e-06      |
# | fps                | 578           |
# | n_updates          | 62            |
# | policy_entropy     | 2.832182      |
# | policy_loss        | -0.0013063751 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 15.3          |
# | total_timesteps    | 7936          |
# | value_loss         | 3897858600.0  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.337383e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 1.37e-06     |
# | fps                | 597          |
# | n_updates          | 63           |
# | policy_entropy     | 2.831047     |
# | policy_loss        | 0.0002665408 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 15.6         |
# | total_timesteps    | 8064         |
# | value_loss         | 3542784500.0 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007006527 |
# | clipfrac           | 0.0          |
# | explained_variance | -2.26e-06    |
# | fps                | 588          |
# | n_updates          | 64           |
# | policy_entropy     | 2.830807     |
# | policy_loss        | 0.0051190956 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 15.8         |
# | total_timesteps    | 8192         |
# | value_loss         | 3389214200.0 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 9.172194e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.15e-06     |
# | fps                | 598           |
# | n_updates          | 65            |
# | policy_entropy     | 2.8311324     |
# | policy_loss        | 0.00064480654 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 16            |
# | total_timesteps    | 8320          |
# | value_loss         | 4127219200.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023020024  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -3.58e-07     |
# | fps                | 601           |
# | n_updates          | 66            |
# | policy_entropy     | 2.8318894     |
# | policy_loss        | -0.0010496795 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 16.2          |
# | total_timesteps    | 8448          |
# | value_loss         | 3495198200.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027748736 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.67e-05      |
# | fps                | 601           |
# | n_updates          | 67            |
# | policy_entropy     | 2.8324602     |
# | policy_loss        | -0.0018030133 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 16.4          |
# | total_timesteps    | 8576          |
# | value_loss         | 1872703600.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025501807 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000123      |
# | fps                | 602           |
# | n_updates          | 68            |
# | policy_entropy     | 2.8325286     |
# | policy_loss        | -0.0013168226 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 16.6          |
# | total_timesteps    | 8704          |
# | value_loss         | 2199102.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022614026 |
# | clipfrac           | 0.0           |
# | explained_variance | 4.9e-05       |
# | fps                | 601           |
# | n_updates          | 69            |
# | policy_entropy     | 2.8308234     |
# | policy_loss        | -0.0018284366 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 16.8          |
# | total_timesteps    | 8832          |
# | value_loss         | 16440851.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001701229  |
# | clipfrac           | 0.0078125    |
# | explained_variance | -3.1e-05     |
# | fps                | 602          |
# | n_updates          | 70           |
# | policy_entropy     | 2.829213     |
# | policy_loss        | -0.009869809 |
# | serial_timesteps   | 8960         |
# | time_elapsed       | 17.1         |
# | total_timesteps    | 8960         |
# | value_loss         | 85204010.0   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0010977512 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.55e-06    |
# | fps                | 598          |
# | n_updates          | 71           |
# | policy_entropy     | 2.8272285    |
# | policy_loss        | -0.000976797 |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 17.3         |
# | total_timesteps    | 9088         |
# | value_loss         | 181818940.0  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00010206492 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.27e-05      |
# | fps                | 599           |
# | n_updates          | 72            |
# | policy_entropy     | 2.8266006     |
# | policy_loss        | 6.469205e-05  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 17.5          |
# | total_timesteps    | 9216          |
# | value_loss         | 301306560.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027650964 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.65e-06     |
# | fps                | 594           |
# | n_updates          | 73            |
# | policy_entropy     | 2.826415      |
# | policy_loss        | 0.0017709117  |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 17.7          |
# | total_timesteps    | 9344          |
# | value_loss         | 223654740.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019043896  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 1.36e-05      |
# | fps                | 579           |
# | n_updates          | 74            |
# | policy_entropy     | 2.8267639     |
# | policy_loss        | 0.00048558053 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 17.9          |
# | total_timesteps    | 9472          |
# | value_loss         | 199864540.0   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00016869756  |
# | clipfrac           | 0.0            |
# | explained_variance | -3.81e-06      |
# | fps                | 599            |
# | n_updates          | 75             |
# | policy_entropy     | 2.8270602      |
# | policy_loss        | -0.00040434697 |
# | serial_timesteps   | 9600           |
# | time_elapsed       | 18.1           |
# | total_timesteps    | 9600           |
# | value_loss         | 245327340.0    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00074525096 |
# | clipfrac           | 0.0           |
# | explained_variance | 6.5e-06       |
# | fps                | 595           |
# | n_updates          | 76            |
# | policy_entropy     | 2.8270223     |
# | policy_loss        | 0.0028026348  |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 18.4          |
# | total_timesteps    | 9728          |
# | value_loss         | 876822660.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.8089693e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.54e-07     |
# | fps                | 599           |
# | n_updates          | 77            |
# | policy_entropy     | 2.8282225     |
# | policy_loss        | 0.00021731027 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 9856          |
# | value_loss         | 824927360.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040077526 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.38e-07      |
# | fps                | 601           |
# | n_updates          | 78            |
# | policy_entropy     | 2.8288817     |
# | policy_loss        | 8.291879e-05  |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 18.8          |
# | total_timesteps    | 9984          |
# | value_loss         | 1453521700.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010206802 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.91e-06     |
# | fps                | 597           |
# | n_updates          | 79            |
# | policy_entropy     | 2.8271205     |
# | policy_loss        | 0.00074634945 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 19            |
# | total_timesteps    | 10112         |
# | value_loss         | 4115936000.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.1562034e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.58e-06     |
# | fps                | 598           |
# | n_updates          | 80            |
# | policy_entropy     | 2.8256752     |
# | policy_loss        | -2.771616e-05 |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 19.2          |
# | total_timesteps    | 10240         |
# | value_loss         | 2537035800.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.124159e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 596           |
# | n_updates          | 81            |
# | policy_entropy     | 2.8238666     |
# | policy_loss        | 0.0006922358  |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 19.4          |
# | total_timesteps    | 10368         |
# | value_loss         | 12690889000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013287942  |
# | clipfrac           | 0.0           |
# | explained_variance | -1.31e-06     |
# | fps                | 595           |
# | n_updates          | 82            |
# | policy_entropy     | 2.8228345     |
# | policy_loss        | 0.0050444202  |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 19.6          |
# | total_timesteps    | 10496         |
# | value_loss         | 25680228000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0005310024   |
# | clipfrac           | 0.0            |
# | explained_variance | 1.79e-07       |
# | fps                | 603            |
# | n_updates          | 83             |
# | policy_entropy     | 2.8215232      |
# | policy_loss        | -0.00080943573 |
# | serial_timesteps   | 10624          |
# | time_elapsed       | 19.9           |
# | total_timesteps    | 10624          |
# | value_loss         | 38453117000.0  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00026240962 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.96e-07     |
# | fps                | 600           |
# | n_updates          | 84            |
# | policy_entropy     | 2.8204632     |
# | policy_loss        | -0.0010992095 |
# | serial_timesteps   | 10752         |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 10752         |
# | value_loss         | 41672868000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00010991648  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.38e-07      |
# | fps                | 600            |
# | n_updates          | 85             |
# | policy_entropy     | 2.8196332      |
# | policy_loss        | -0.00039461616 |
# | serial_timesteps   | 10880          |
# | time_elapsed       | 20.3           |
# | total_timesteps    | 10880          |
# | value_loss         | 66710794000.0  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0001619864  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.77e-07     |
# | fps                | 603           |
# | n_updates          | 86            |
# | policy_entropy     | 2.8192291     |
# | policy_loss        | 0.0018399016  |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 20.5          |
# | total_timesteps    | 11008         |
# | value_loss         | 81336386000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00030916542 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 595           |
# | n_updates          | 87            |
# | policy_entropy     | 2.8193057     |
# | policy_loss        | 0.0026908736  |
# | serial_timesteps   | 11136         |
# | time_elapsed       | 20.7          |
# | total_timesteps    | 11136         |
# | value_loss         | 41225937000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00040658948  |
# | clipfrac           | 0.0            |
# | explained_variance | 3.58e-07       |
# | fps                | 596            |
# | n_updates          | 88             |
# | policy_entropy     | 2.8197477      |
# | policy_loss        | -0.0016086389  |
# | serial_timesteps   | 11264          |
# | time_elapsed       | 20.9           |
# | total_timesteps    | 11264          |
# | value_loss         | 176235680000.0 |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00035712664  |
# | clipfrac           | 0.0            |
# | explained_variance | -3.58e-07      |
# | fps                | 603            |
# | n_updates          | 89             |
# | policy_entropy     | 2.8198977      |
# | policy_loss        | -0.001899506   |
# | serial_timesteps   | 11392          |
# | time_elapsed       | 21.1           |
# | total_timesteps    | 11392          |
# | value_loss         | 181223620000.0 |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00014898014  |
# | clipfrac           | 0.0            |
# | explained_variance | 0              |
# | fps                | 598            |
# | n_updates          | 90             |
# | policy_entropy     | 2.8194182      |
# | policy_loss        | 8.415873e-05   |
# | serial_timesteps   | 11520          |
# | time_elapsed       | 21.4           |
# | total_timesteps    | 11520          |
# | value_loss         | 173397230000.0 |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0009997596   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.19e-07      |
# | fps                | 599            |
# | n_updates          | 91             |
# | policy_entropy     | 2.8194175      |
# | policy_loss        | 0.0020425522   |
# | serial_timesteps   | 11648          |
# | time_elapsed       | 21.6           |
# ...
# | serial_timesteps   | 17280          |
# | time_elapsed       | 31             |
# | total_timesteps    | 17280          |
# | value_loss         | 915040900000.0 |
# ---------------------------------------
# ----------------------------------------
# | approxkl           | 1.0809626e-05   |
# | clipfrac           | 0.0             |
# | explained_variance | 1.19e-07        |
# | fps                | 597             |
# | n_updates          | 136             |
# | policy_entropy     | 2.8141723       |
# | policy_loss        | -0.00021410023  |
# | serial_timesteps   | 17408           |
# | time_elapsed       | 31.2            |
# | total_timesteps    | 17408           |
# | value_loss         | 1650516700000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 0.0014650171    |
# | clipfrac           | 0.00390625      |
# | explained_variance | 0               |
# | fps                | 596             |
# | n_updates          | 137             |
# | policy_entropy     | 2.8147845       |
# | policy_loss        | -2.385117e-06   |
# | serial_timesteps   | 17536           |
# | time_elapsed       | 31.4            |
# | total_timesteps    | 17536           |
# | value_loss         | 1607500600000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 4.8012356e-05   |
# | clipfrac           | 0.0             |
# | explained_variance | 0               |
# | fps                | 603             |
# | n_updates          | 138             |
# | policy_entropy     | 2.8152027       |
# | policy_loss        | 0.00078518793   |
# | serial_timesteps   | 17664           |
# | time_elapsed       | 31.6            |
# | total_timesteps    | 17664           |
# | value_loss         | 1795544600000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 1.7423312e-06   |
# | clipfrac           | 0.0             |
# | explained_variance | 5.96e-08        |
# | fps                | 599             |
# | n_updates          | 139             |
# | policy_entropy     | 2.815281        |
# | policy_loss        | -5.6897406e-05  |
# | serial_timesteps   | 17792           |
# | time_elapsed       | 31.9            |
# | total_timesteps    | 17792           |
# | value_loss         | 1999112900000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 6.006715e-08    |
# | clipfrac           | 0.0             |
# | explained_variance | 5.96e-08        |
# | fps                | 601             |
# | n_updates          | 140             |
# | policy_entropy     | 2.8152952       |
# | policy_loss        | -1.8068764e-05  |
# | serial_timesteps   | 17920           |
# | time_elapsed       | 32.1            |
# | total_timesteps    | 17920           |
# | value_loss         | 2130463200000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 1.2348167e-09   |
# | clipfrac           | 0.0             |
# | explained_variance | 0               |
# | fps                | 603             |
# | n_updates          | 141             |
# | policy_entropy     | 2.8152986       |
# | policy_loss        | -1.4081015e-06  |
# | serial_timesteps   | 18048           |
# | time_elapsed       | 32.3            |
# | total_timesteps    | 18048           |
# | value_loss         | 1476788900000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 5.5476346e-11   |
# | clipfrac           | 0.0             |
# | explained_variance | -1.19e-07       |
# | fps                | 572             |
# | n_updates          | 142             |
# | policy_entropy     | 2.8152988       |
# | policy_loss        | 1.0762597e-06   |
# | serial_timesteps   | 18176           |
# | time_elapsed       | 32.5            |
# | total_timesteps    | 18176           |
# | value_loss         | 2308006700000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 4.643508e-13    |
# | clipfrac           | 0.0             |
# | explained_variance | -1.19e-07       |
# | fps                | 599             |
# | n_updates          | 143             |
# | policy_entropy     | 2.8152988       |
# | policy_loss        | -1.7159618e-07  |
# | serial_timesteps   | 18304           |
# | time_elapsed       | 32.7            |
# | total_timesteps    | 18304           |
# | value_loss         | 1424578800000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 0.00024339747   |
# | clipfrac           | 0.0             |
# | explained_variance | 2.38e-07        |
# | fps                | 594             |
# | n_updates          | 144             |
# | policy_entropy     | 2.8156626       |
# | policy_loss        | -0.0022035232   |
# | serial_timesteps   | 18432           |
# | time_elapsed       | 32.9            |
# | total_timesteps    | 18432           |
# | value_loss         | 1874429300000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 9.605337e-06    |
# | clipfrac           | 0.0             |
# | explained_variance | 1.19e-07        |
# | fps                | 597             |
# | n_updates          | 145             |
# | policy_entropy     | 2.8159144       |
# | policy_loss        | 7.604796e-05    |
# | serial_timesteps   | 18560           |
# | time_elapsed       | 33.2            |
# | total_timesteps    | 18560           |
# | value_loss         | 1680926700000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 3.6758928e-07   |
# | clipfrac           | 0.0             |
# | explained_variance | 0               |
# | fps                | 598             |
# | n_updates          | 146             |
# | policy_entropy     | 2.8159616       |
# | policy_loss        | -4.3098e-05     |
# | serial_timesteps   | 18688           |
# | time_elapsed       | 33.4            |
# | total_timesteps    | 18688           |
# | value_loss         | 1960809900000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 1.3227126e-08   |
# | clipfrac           | 0.0             |
# | explained_variance | 0               |
# | fps                | 604             |
# | n_updates          | 147             |
# | policy_entropy     | 2.8159707       |
# | policy_loss        | 2.2591557e-06   |
# | serial_timesteps   | 18816           |
# | time_elapsed       | 33.6            |
# | total_timesteps    | 18816           |
# | value_loss         | 3860813000000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 5.835158e-10    |
# | clipfrac           | 0.0             |
# | explained_variance | -2.38e-07       |
# | fps                | 602             |
# | n_updates          | 148             |
# | policy_entropy     | 2.8159716       |
# | policy_loss        | 4.540896e-06    |
# | serial_timesteps   | 18944           |
# | time_elapsed       | 33.8            |
# | total_timesteps    | 18944           |
# | value_loss         | 3654837300000.0 |
# ----------------------------------------
# ----------------------------------------
# | approxkl           | 1.1650847e-11   |
# | clipfrac           | 0.0             |
# | explained_variance | 1.19e-07        |
# | fps                | 603             |
# | n_updates          | 149             |
# | policy_entropy     | 2.8159719       |
# | policy_loss        | -3.662426e-07   |
# | serial_timesteps   | 19072           |
# | time_elapsed       | 34              |
# | total_timesteps    | 19072           |
# | value_loss         | 1491492000000.0 |
# ----------------------------------------
# --------------------------------------
# | approxkl           | 1.7179553e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.43e-06     |
# | fps                | 600           |
# | n_updates          | 150           |
# | policy_entropy     | 2.8159065     |
# | policy_loss        | 0.00025801023 |
# | serial_timesteps   | 19200         |
# | time_elapsed       | 34.2          |
# | total_timesteps    | 19200         |
# | value_loss         | 1262484000.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010203187  |
# | clipfrac           | 0.0           |
# | explained_variance | 1.79e-07      |
# | fps                | 601           |
# | n_updates          | 151           |
# | policy_entropy     | 2.8142312     |
# | policy_loss        | 0.006458044   |
# | serial_timesteps   | 19328         |
# | time_elapsed       | 34.4          |
# | total_timesteps    | 19328         |
# | value_loss         | 10877469000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021103883 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.19e-07     |
# | fps                | 598           |
# | n_updates          | 152           |
# | policy_entropy     | 2.813626      |
# | policy_loss        | 0.00014803244 |
# | serial_timesteps   | 19456         |
# | time_elapsed       | 34.6          |
# | total_timesteps    | 19456         |
# | value_loss         | 46016565000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00057442003  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.38e-07      |
# | fps                | 601            |
# | n_updates          | 153            |
# | policy_entropy     | 2.8141038      |
# | policy_loss        | 0.006908828    |
# | serial_timesteps   | 19584          |
# | time_elapsed       | 34.9           |
# | total_timesteps    | 19584          |
# | value_loss         | 122737120000.0 |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.5521893e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.19e-07       |
# | fps                | 588            |
# | n_updates          | 154            |
# | policy_entropy     | 2.8144586      |
# | policy_loss        | 0.0005711113   |
# | serial_timesteps   | 19712          |
# | time_elapsed       | 35.1           |
# | total_timesteps    | 19712          |
# | value_loss         | 184203380000.0 |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00036766086 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 597           |
# | n_updates          | 155           |
# | policy_entropy     | 2.814523      |
# | policy_loss        | 0.0035739052  |
# | serial_timesteps   | 19840         |
# | time_elapsed       | 35.3          |
# | total_timesteps    | 19840         |
# | value_loss         | 66023870000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00042987874  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.19e-07       |
# | fps                | 601            |
# | n_updates          | 156            |
# | policy_entropy     | 2.812753       |
# | policy_loss        | 0.0022873306   |
# | serial_timesteps   | 19968          |
# | time_elapsed       | 35.5           |
# | total_timesteps    | 19968          |
# | value_loss         | 187541210000.0 |
# ---------------------------------------
# Step: 660
# Balance: 10000
# Shares held: 0 (Total sold: 0)
# Avg cost for held shares: 0 (Total sales value: 0)
# Net worth: 10000.0 (Max net worth: 10000)
# Profit: 0.0
# Step: 760
# Balance: 0.3881186931175762
# Shares held: 613 (Total sold: 1903)
# Avg cost for held shares: 15.962459396230368 (Total sales value: 42102.96546641121)
# Net worth: 10146.053937154746 (Max net worth: 12494.129818837055)
# Profit: 146.05393715474565
# Step: 860
# Balance: 4831.577958751018
# Shares held: 218 (Total sold: 4834)
# Avg cost for held shares: 23.54080101807545 (Total sales value: 101678.74984261763)
# Net worth: 9156.866176370942 (Max net worth: 12494.129818837055)
# Profit: -843.1338236290576
# Step: 960
# Balance: 8135.351155135135
# Shares held: 0 (Total sold: 7830)
# Avg cost for held shares: 0 (Total sales value: 161467.6590154808)
# Net worth: 8135.351155135135 (Max net worth: 12494.129818837055)
# Profit: -1864.6488448648652
# Step: 1060
# Balance: 9098.97821289269
# Shares held: 0 (Total sold: 10050)
# Avg cost for held shares: 0 (Total sales value: 210950.71335095147)
# Net worth: 9098.97821289269 (Max net worth: 12494.129818837055)
# Profit: -901.0217871073091
# Step: 1160
# Balance: 4293.149341377449
# Shares held: 254 (Total sold: 12561)
# Avg cost for held shares: 14.968687298753554 (Total sales value: 258456.5183703428)
# Net worth: 8077.881676596651 (Max net worth: 12494.129818837055)
# Profit: -1922.1183234033488
# Step: 1260
# Balance: 9.529570827405223
# Shares held: 570 (Total sold: 14860)
# Avg cost for held shares: 14.942045343842782 (Total sales value: 292907.0896977119)
# Net worth: 8463.305041477888 (Max net worth: 12494.129818837055)
# Profit: -1536.6949585221118
# Step: 1360
# Balance: 10526.844321407798
# Shares held: 0 (Total sold: 17540)
# Avg cost for held shares: 0 (Total sales value: 334261.6150819742)
# Net worth: 10526.844321407798 (Max net worth: 12494.129818837055)
# Profit: 526.8443214077979
# Step: 1460
# Balance: 3264.9832525339234
# Shares held: 343 (Total sold: 19113)
# Avg cost for held shares: 21.816129698035258 (Total sales value: 367285.7978503935)
# Net worth: 11095.817036699671 (Max net worth: 12494.129818837055)
# Profit: 1095.817036699671
# Step: 1560
# Balance: 10751.766675729681
# Shares held: 0 (Total sold: 21510)
# Avg cost for held shares: 0 (Total sales value: 420376.56662062666)
# Net worth: 10751.766675729681 (Max net worth: 12494.129818837055)
# Profit: 751.7666757296811
# Step: 1660
# Balance: 10485.814207092493
# Shares held: 0 (Total sold: 22513)
# Avg cost for held shares: 0 (Total sales value: 450638.78371797816)
# Net worth: 10485.814207092493 (Max net worth: 12494.129818837055)
# Profit: 485.81420709249323
# Step: 1760
# Balance: 12672.474781104453
# Shares held: 0 (Total sold: 22896)
# Avg cost for held shares: 0 (Total sales value: 471242.01414689195)
# Net worth: 12672.474781104453 (Max net worth: 13497.093043230021)
# Profit: 2672.4747811044526
# Step: 1860
# Balance: 11164.226201026897
# Shares held: 0 (Total sold: 23892)
# Avg cost for held shares: 0 (Total sales value: 519336.95104736544)
# Net worth: 11164.226201026897 (Max net worth: 13497.093043230021)
# Profit: 1164.226201026897
# Step: 1960
# Balance: 13692.754038085559
# Shares held: 0 (Total sold: 24543)
# Avg cost for held shares: 0 (Total sales value: 549701.8894804294)
# Net worth: 13692.754038085559 (Max net worth: 13726.45979354484)
# Profit: 3692.754038085559
# Step: 2060
# Balance: 12464.907727671965
# Shares held: 37 (Total sold: 25486)
# Avg cost for held shares: 65.89820357918059 (Total sales value: 614982.009313867)
# Net worth: 14894.141894325181 (Max net worth: 16055.557382796924)
# Profit: 4894.141894325181
# Step: 2160
# Balance: 4826.5593806908155
# Shares held: 187 (Total sold: 26038)
# Avg cost for held shares: 51.2736931684249 (Total sales value: 646521.983641735)
# Net worth: 17702.73683257217 (Max net worth: 17702.73683257217)
# Profit: 7702.736832572169
# Step: 2260
# Balance: 19673.224180557165
# Shares held: 0 (Total sold: 27065)
# Avg cost for held shares: 0 (Total sales value: 725262.3470618782)
# Net worth: 19673.224180557165 (Max net worth: 20027.66382201619)
# Profit: 9673.224180557165
# Step: 2360
# Balance: 15930.2214012445
# Shares held: 60 (Total sold: 27996)
# Avg cost for held shares: 112.72366903359563 (Total sales value: 816099.9310104863)
# Net worth: 22693.641543260237 (Max net worth: 22693.641543260237)
# Profit: 12693.641543260237
# Step: 2460
# Balance: 26435.65715965426
# Shares held: 0 (Total sold: 28592)
# Avg cost for held shares: 0 (Total sales value: 897294.9234708886)
# Net worth: 26435.65715965426 (Max net worth: 26435.65715965426)
# Profit: 16435.65715965426
# Step: 2560
# Balance: 25889.495602398652
# Shares held: 0 (Total sold: 29051)
# Avg cost for held shares: 0 (Total sales value: 973186.1704775265)
# Net worth: 25889.495602398652 (Max net worth: 31039.880059692467)
# Profit: 15889.495602398652
